# %% [markdown]
# # Image Rotation

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in E:\anaconda\Lib\site-packages (12.3.0)

# %%
from PIL import Image

# Take image name as input
image_name = input("Enter the image name: ")

# Open the image
img = Image.open(image_name)

# Take rotation angle
angle = int(input("Enter rotation angle: "))

# Rotate the image
rotated_img = img.rotate(angle)

# Save the rotated image
rotated_img.save("rotated_image.jpg")

# Display the rotated image
rotated_img.show()

print("Image rotated successfully!")
print("Output saved as rotated_image.jpg")
# Out:
# Enter the image name:  sc.jpg
# Enter rotation angle:  45
# Image rotated successfully!
# Output saved as rotated_image.jpg

# %%
# Thus the program was executed successfully
